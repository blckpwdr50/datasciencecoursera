# %% [markdown]
# <a href="https://colab.research.google.com/github/blckpwdr50/datasciencecoursera/blob/master/TRAIN_HS_PD_Lab_15_%5BDaniel_Schaben%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab 15: Computer Vision**
# ---
#
#
# ### **Description**
# This lab focuses on how we can apply our Deep Learning skills to the field of Computer Vision.
#
#
# <br>
#
# ### **Lab Structure**
# * **Part 1**: [MNIST Digit Classifiction](#p1)
#
# * **Part 2**: [Kuzushiji-MNIST Letter Classifiction](#p2)
#
# * **Part 3**: [[OPTIONAL] CIFAR-100 General Image Classifiction](#p3)
#
#
# <br>
#
# ### **Goals**
# By the end of this lab, you will:
# * Learn how to work with image data.
# * Train and evaluate Neural Networks for Computer Vision tasks.
#
# <br>
#
#
# ### **Cheat Sheets**:
# * [Deep Learning with keras](https://docs.google.com/document/d/1vc51G6X8ERimrVW6kuyIXNcumR-34-SNiUXA8IYK_1o/edit?usp=sharing)
#
# <br>
#
# **Before starting, run the code below to import all necessary functions and libraries.**

# %%
from keras.models import Sequential
from keras.layers import *

from IPython.display import Image
from keras.datasets import mnist, cifar100
from torchvision.datasets import KMNIST
from keras.optimizers import Adam, SGD
from keras.utils import to_categorical

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# <a name="p1"></a>
#
# ---
# ## **Part 1: MNIST Digit Classification**
# ---
#
# In this section, we will build, fit, and evaluate Neural Networks for classifying handwritten digits.

# %% [markdown]
# ### **Problem #1.1**
#
# To get started, let's:
# 1. Load and view the data.
# 2. Scale the features.
# 3. One hot encode the labels.

# %% [markdown]
# #### **1. Load and view the data.**

# %%
# import
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Show a few images from the dataset
plt.figure(figsize=(20,5))
for i in range(5):
  plt.subplot(1, 5, i+1)
  plt.title(f"Random image from class {y_train[i]}")
  plt.imshow(X_train[i], cmap='gray')
  plt.axis("off")

plt.show()

# %% [markdown]
# #### **2. Scale the features.**
#
# Specifically, we want to just scale the inputs to be between 0 and 1 without impacting the mean or standard deviation. This means that we *don't* want to normalize or standardize. Instead, we need to scale the points from 0 - 255 to 0 - 1.

# %%
X_train = X_train/255
X_test = X_test/255

# %% [markdown]
# #### **3. One hot encode the labels.**

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# ### **Problem #1.2**
#
# Next, let's determine the shape of the data so that we know how to properly setup the input layer of our Neural Network. Specifically, use `X_train.shape` to see what the dimensions of the data is and decide if it needs to be flattened.
#
# <br>
#
# For example, if the `.shape` method returned the tuple:
# * `(10,5)`, this would tell us that there are 10 data points each with 5 values. This would not need to be flattened.
# * `(10,5,2)`, it would need to be flattened so that instead of each datapoint being a `(5,2)` matrix it is a `(10,0)` flat array.
#
# <br>
#
# **Determine if the data needs to be flattened.**

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# ### **Problem #1.3**
#
# Now let's build and fit a Neural Network to classify these images. Specifically, let's:
# 1. Create a Neural Network and fit it to the training data.
# 2. Print the learned weights and biases.
# 3. Visualize the training and validation performance per epoch.

# %% [markdown]
# #### **1. Create a Neural Network and fit it to the training data.**
#
# Build a NN such that it has:
# * The correct number of input neurons (one for each feature). Flattened if need be.
# * No hidden layers.
# * Ten output neurons with the `'softmax'` activation function. This is the typical output activation function for classification. **NOTE: You need one output neuron per class (digit).**
#
# <br>
#
# Train the NN such that the:
# * `loss = 'categorical_crossentropy'`. This is a typical loss function for one hot encoded categorical variables. It compares the probabilities of outputs.
# * `metrics = ['accuracy']`.

# %%
model_nn = Sequential()
model_nn.add(Flatten(input_shape=(28,28)))
model_nn.add(Dense(10,activation='softmax'))

# Compile the model
opt = Adam(learning_rate = 0.1)
model_nn.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics='accuracy')

# Fit the model on the training data
history = model_nn.fit(X_train, y_train, validation_split = 0.1, epochs=10, batch_size = 16)
# Out:
# Epoch 1/10
# 3375/3375 [==============================] - 13s 3ms/step - loss: 2.5654 - accuracy: 0.8530 - val_loss: 2.6736 - val_accuracy: 0.8735
# Epoch 2/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 2.8134 - accuracy: 0.8781 - val_loss: 2.5237 - val_accuracy: 0.8895
# Epoch 3/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 2.7959 - accuracy: 0.8824 - val_loss: 2.4325 - val_accuracy: 0.8980
# Epoch 4/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 2.7924 - accuracy: 0.8830 - val_loss: 2.3550 - val_accuracy: 0.8992
# Epoch 5/10
# 3375/3375 [==============================] - 10s 3ms/step - loss: 2.8416 - accuracy: 0.8873 - val_loss: 2.5832 - val_accuracy: 0.9002
# Epoch 6/10
# 3375/3375 [==============================] - 11s 3ms/step - loss: 2.8939 - accuracy: 0.8858 - val_loss: 3.4202 - val_accuracy: 0.8615
# Epoch 7/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 2.8853 - accuracy: 0.8887 - val_loss: 2.6318 - val_accuracy: 0.8993
# Epoch 8/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 2.8430 - accuracy: 0.8884 - val_loss: 2.9950 - val_accuracy: 0.8880
# Epoch 9/10
# 3375/3375 [==============================] - 11s 3ms/step - loss: 2.8270 - accuracy: 0.8912 - val_loss: 2.5455 - val_accuracy: 0.9047
# Epoch 10/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 2.8300 - accuracy: 0.8890 - val_loss: 2.5918 - val_accuracy: 0.9077

# %% [markdown]
# #### **2. Print the learned weights and biases.**
#
# **NOTE**: One of the main strengths of Deep Learning is its ability to learn an enormous number of parameters (weights and biases). This also means that looking at those parameters individually starts lose much meaning.

# %%
layers = model_nn.layers

for i in range(len(layers)):
  print('\nLayer ' + str(i))
  if len(layers[i].get_weights()) > 0:
    print('Weights: \n' + str(layers[i].get_weights()[0]))
    print('\nBiases: \n' + str(layers[i].get_weights()[1]))
# Out:
# Layer 0
#
# Layer 1
# Weights:
# [[ 0.05390874  0.06179654 -0.01867214 ...  0.04558343 -0.03116967
#   -0.04022299]
#  [ 0.04664481 -0.01061074 -0.00119771 ... -0.03390888  0.00871833
#    0.01246499]
#  [-0.05864715 -0.08030515 -0.02326197 ...  0.04710194  0.05879702
#    0.05407972]
#  ...
#  [-0.01925455  0.00958226  0.05991248 ...  0.01110399  0.05784596
#   -0.0809463 ]
#  [ 0.08400897 -0.00487777 -0.02442689 ...  0.08434684 -0.02966649
#    0.01979233]
#  [ 0.03444712  0.07069565  0.04816853 ...  0.05768565 -0.06463036
#   -0.07065811]]
#
# Biases:
# [-24.861893   10.983752    5.3410525  -1.0581182   3.9093227  28.492977
#  -13.271487   17.022667  -21.747097   -4.874609 ]

# %% [markdown]
# #### **3. Visualize the training and validation performance per epoch.**
#
# Specifically, create two plots:
# 1. The loss of the NN vs. epochs for both the training and validation sets.
#
# 2. The accuracy of the NN vs. epochs for both the training and validation sets. You can do this by replaced `'loss'` with `'accuracy'` anywhere you find it in the code.

# %%
# VISUALIZE loss
train_loss = history.history['loss']
plt.plot(train_loss, label = 'Training')

val_loss = history.history['val_loss']
plt.plot(val_loss, label = 'Validation')

plt.title('Loss After Each Epoch', fontsize = 'x-large')
plt.xlabel('Epoch', fontsize = 'x-large')
plt.ylabel('Loss', fontsize = 'x-large')
plt.legend()
plt.show()

# %%
# VISUALIZE
train_accuracy = history.history['accuracy']
plt.plot(train_accuracy, label = 'Training')

val_accuracy = history.history['val_accuracy']
plt.plot(val_accuracy, label = 'Validation')

plt.title('Accuracy After Each Epoch', fontsize = 'x-large')
plt.xlabel('Epoch', fontsize = 'x-large')
plt.ylabel('Accuracy', fontsize = 'x-large')
plt.legend()
plt.show()

# %% [markdown]
# ### **Problem #1.4**
#
# Now, improve this model. Consider:
# * Adding hidden layers with around the same number of neurons as there are input features (pixels).
# * Using non-linear activation functions in any hidden layers.
# * Training with a different learning rate.
# * Training with more epochs.
# * Training with a different batch size.
#
# <br>
#
# Create learning curves to ensure you are creating an improved model.
#
# <br>
#
# **NOTE**: As a benchmark, we were able to train a model that achieved a training accuracy of 99.6% and validation accuracy of 97.9%. See if you can reach or improve upon this, particularly in closing the generalization gap (the difference between the training and validation accuracies).

# %%
model_2=Sequential()
model_2.add(Flatten(input_shape=(28,28)))
model_2.add(Dense(256,activation='sigmoid'))
model_2.add(Dense(64,activation='relu'))
model_2.add(Dense(10,activation='softmax'))

# %%
opt = Adam(learning_rate=0.001)
model_2.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['mse'])

#model_2.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
history = model_2.fit(X_train, y_train, verbose = False, validation_split = 0.1, epochs=10, batch_size = 32)
#history=model_2.fit(X_train,y_train,verbose= =True, validation_split=0.1,epochs=15,batch_size=32)

# %%
# VISUALIZE loss
train_loss = history.history['loss']
plt.plot(train_loss, label = 'Training')

val_loss = history.history['val_loss']
plt.plot(val_loss, label = 'Validation')

plt.title('Loss After Each Epoch', fontsize = 'x-large')
plt.xlabel('Epoch', fontsize = 'x-large')
plt.ylabel('Loss', fontsize = 'x-large')
plt.legend()
plt.show()

# %%
# VISUALIZE
train_accuracy = history.history['accuracy']
plt.plot(train_accuracy, label = 'Training')

val_accuracy = history.history['val_accuracy']
plt.plot(val_accuracy, label = 'Validation')

plt.title('Accuracy After Each Epoch', fontsize = 'x-large')
plt.xlabel('Epoch', fontsize = 'x-large')
plt.ylabel('Accuracy', fontsize = 'x-large')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-154d83c2ff87> in <cell line: 2>()
#       1 # VISUALIZE
# ----> 2 train_accuracy = history.history['accuracy']
#       3 plt.plot(train_accuracy, label = 'Training')
#       4
#       5 val_accuracy = history.history['val_accuracy']
#
# KeyError: 'accuracy'

# %% [markdown]
# ### **Problem #1.5**
#
# **Run the code below to make predictions on the test set using your final model.**

# %%
# Make predictions and convert from probabilities of each digit to single digit
predictions = [np.argmax(d) for d in model_nn.predict(X_test)]


# Plot images with predicted labels
plt.figure(figsize=(20,5))

for i in range(5):
  plt.subplot(1, 5, i+1)
  plt.title(f"Model predicts {predictions[i]}, Actual is {np.argmax(y_test[i])}")
  plt.imshow(X_test[i], cmap='gray')
  plt.axis("off")

plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# <a name="p2"></a>
#
# ---
# ## **Part 2: Kuzushiji-MNIST Letter Classifiction**
# ---
#
# ![Kanji](https://raw.githubusercontent.com/rois-codh/kmnist/master/images/kkanji_examples.png)
#
# <center>
#
# *Image taken from the Kuzushiji-MNIST dataset.*
#
# </center>
#
# <br>
#
# The `K-MNIST` dataset is a newer MNIST-like dataset containing 10 phonetic letters of Hiragana, a Japanese syllabary and component of the Japanese writing system. One intention of the dataset was to link Hiragana from classical literature to modern counterparts (UTF-8 encoded).
#
# Using deep learning, you will develop and evaluate various neural networks to train an AI in image recognition. This project will challenge you to design your own neural networks and evaluate how your choices of hyperparameters impacted your models' accuracies.
#
# <br>
#
# **Your goal is to create a model that classifies the Hirgana letters from the test dataset with 90% accuracy or more.**

# %% [markdown]
# ### **Problem #2.1**
#
# To get started, let's:
# 1. Load and view the data.
# 2. Scale the features.
# 3. One hot encode the labels.

# %% [markdown]
# #### **1. Load and view the data.**

# %%
kmnist_train = KMNIST('.', download='true')
X_train, y_train = kmnist_train.train_data.data.numpy(), kmnist_train.train_labels

kmnist_test = KMNIST('.', download='true', train=False)
X_test, y_test = kmnist_test.test_data.data.numpy(), kmnist_test.test_labels


plt.figure(figsize=(20,5))

# Show a few images from the dataset
for i in range(5):
  plt.subplot(1, 5, i + 1)
  plt.title(f"Random image from class {y_train[i]}")
  plt.imshow(X_train[i], cmap='gray')
  plt.axis("off")

plt.show()
# Out:
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-images-idx3-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-images-idx3-ubyte.gz to ./KMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 18165135/18165135 [00:09<00:00, 1877385.81it/s]
# Extracting ./KMNIST/raw/train-images-idx3-ubyte.gz to ./KMNIST/raw
#
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-labels-idx1-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-labels-idx1-ubyte.gz to ./KMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29497/29497 [00:00<00:00, 376196.56it/s]
# Extracting ./KMNIST/raw/train-labels-idx1-ubyte.gz to ./KMNIST/raw
#
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-images-idx3-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-images-idx3-ubyte.gz to ./KMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 3041136/3041136 [00:02<00:00, 1245558.81it/s]
# Extracting ./KMNIST/raw/t10k-images-idx3-ubyte.gz to ./KMNIST/raw
#
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-labels-idx1-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-labels-idx1-ubyte.gz to ./KMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5120/5120 [00:00<00:00, 5729678.89it/s]
# Extracting ./KMNIST/raw/t10k-labels-idx1-ubyte.gz to ./KMNIST/raw
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/mnist.py:75: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/mnist.py:65: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/mnist.py:80: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/mnist.py:70: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")

# %% [markdown]
# #### **2. Scale the features.**
#
# Specifically, we want to just scale the inputs to be between 0 and 1 without impacting the mean or standard deviation. This means that we *don't* want to normalize or standardize. Instead, we need to scale the points from 0 - 255 to 0 - 1.

# %%
X_train = X_train/255
X_test = X_test/255

# %% [markdown]
# #### **3. One hot encode the labels.**

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# ### **Problem #2.2**
#
# Next, let's determine the shape of the data so that we know how to properly setup the input layer of our Neural Network.
#
# <br>
#
# **IMPORTANT**: While we knew there 10 digits/labels in the Part above, we may not always be familiar with the label enough to know how many unique categories there are. While this is something that is important to verify, we can quickly check how many categories were created for the label by looking at `y_train.shape`.

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000, 10)

# %% [markdown]
# ### **Problem #2.3**
#
# Now let's build and fit a Neural Network to classify these images. Specifically, let's:
# 1. Create a Neural Network and fit it to the training data.
# 2. Visualize the training and validation performance per epoch.
#
# <br>
#
# **NOTE**: As mentioned in Part 1, viewing the learned weights and biases is *usually* not very meaningful when there are so many of them. As such, you are not required to do that here.

# %% [markdown]
# #### **1. Create a Neural Network and fit it to the training data.**
#
# Build a NN such that it has:
# * The correct number of input neurons (one for each feature). Flattened if need be.
# * No hidden layers.
# * Ten output neurons with the `'softmax'` activation function. This is the typical output activation function for classification. **NOTE: You need one output neuron per class (letter).**
#
# <br>
#
# Train the NN such that the:
# * `loss = 'categorical_crossentropy'`. This is a typical loss function for one hot encoded categorical variables. It compares the probabilities of outputs.
# * `metrics = ['accuracy']`.

# %%
model_nn = Sequential()
model_nn.add(Flatten(input_shape = (28, 28)))
model_nn.add(Dense(10, activation='softmax'))

# Compile the model
opt = Adam(learning_rate = 0.1)
model_nn.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# Fit the model on the training data
history = model_nn.fit(X_train, y_train, verbose = True, validation_split = 0.1, epochs=10, batch_size = 16)
# Out:
# Epoch 1/10
# 3375/3375 [==============================] - 11s 3ms/step - loss: 6.6323 - accuracy: 0.7191 - val_loss: 6.6164 - val_accuracy: 0.7607
# Epoch 2/10
# 3375/3375 [==============================] - 10s 3ms/step - loss: 6.9795 - accuracy: 0.7430 - val_loss: 7.6032 - val_accuracy: 0.7362
# Epoch 3/10
# 3375/3375 [==============================] - 11s 3ms/step - loss: 7.1133 - accuracy: 0.7462 - val_loss: 8.5243 - val_accuracy: 0.7125
# Epoch 4/10
# 3375/3375 [==============================] - 12s 4ms/step - loss: 7.0959 - accuracy: 0.7494 - val_loss: 7.2025 - val_accuracy: 0.7482
# Epoch 5/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 7.1229 - accuracy: 0.7531 - val_loss: 8.1671 - val_accuracy: 0.7338
# Epoch 6/10
# 3375/3375 [==============================] - 10s 3ms/step - loss: 7.0392 - accuracy: 0.7517 - val_loss: 7.6300 - val_accuracy: 0.7362
# Epoch 7/10
# 3375/3375 [==============================] - 10s 3ms/step - loss: 7.2291 - accuracy: 0.7531 - val_loss: 10.4085 - val_accuracy: 0.6848
# Epoch 8/10
# 3375/3375 [==============================] - 10s 3ms/step - loss: 7.1412 - accuracy: 0.7532 - val_loss: 7.6043 - val_accuracy: 0.7487
# Epoch 9/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 7.1269 - accuracy: 0.7540 - val_loss: 7.3343 - val_accuracy: 0.7713
# Epoch 10/10
# 3375/3375 [==============================] - 10s 3ms/step - loss: 7.2644 - accuracy: 0.7538 - val_loss: 7.8061 - val_accuracy: 0.7518

# %% [markdown]
# #### **2. Visualize the training and validation performance per epoch.**
#
# Specifically, create two plots:
# 1. The loss of the NN vs. epochs for both the training and validation sets.
#
# 2. The accuracy of the NN vs. epochs for both the training and validation sets. You can do this by replaced `'loss'` with `'accuracy'` anywhere you find it in the code.

# %%
# VISUALIZE
train_loss = history.history['loss']
plt.plot(train_loss, label = 'Training')

val_loss = history.history['val_loss']
plt.plot(val_loss, label = 'Validation')

plt.title('Loss After Each Epoch', fontsize = 'x-large')
plt.xlabel('Epoch', fontsize = 'x-large')
plt.ylabel('Loss', fontsize = 'x-large')
plt.legend()
plt.show()

# %%
# VISUALIZE
train_accuracy = history.history['accuracy']
plt.plot(train_accuracy, label = 'Training')

val_accuracy = history.history['val_accuracy']
plt.plot(val_accuracy, label = 'Validation')

plt.title('Accuracy After Each Epoch', fontsize = 'x-large')
plt.xlabel('Epoch', fontsize = 'x-large')
plt.ylabel('Accuracy', fontsize = 'x-large')
plt.legend()
plt.show()

# %% [markdown]
# ### **Problem #2.4**
#
# Now, improve this model such that it achieves at least a 90% accuracy on both the training and validation sets. Consider:
# * Adding hidden layers with around the same number of neurons as there are input features (pixels).
# * Using non-linear activation functions in any hidden layers.
# * Training with a different learning rate.
# * Training with more epochs.
# * Training with a different batch size.
#
# <br>
#
# Create learning curves to ensure you are creating an improved model.
#
# <br>
#
# **NOTE**: As a benchmark, we were able to train a model that achieved a training accuracy of 99.3% and validation accuracy of 96.5%. See if you can reach or improve upon this, particularly in closing the generalization gap (the difference between the training and validation accuracies).

# %%
model_nn = Sequential()
model_nn.add(Flatten(input_shape = (28, 28)))
model_nn.add(Dense(512, activation='relu'))
model_nn.add(Dense(256, activation='relu'))
model_nn.add(Dense(10, activation='softmax'))

# Compile the model
opt = Adam(learning_rate = 0.001)
model_nn.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# Fit the model on the training data
history = model_nn.fit(X_train, y_train, verbose = True, validation_split = 0.1, epochs=10, batch_size = 32)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3058 - accuracy: 0.9069 - val_loss: 0.1658 - val_accuracy: 0.9500
# Epoch 2/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.1278 - accuracy: 0.9604 - val_loss: 0.1485 - val_accuracy: 0.9568
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0785 - accuracy: 0.9752 - val_loss: 0.1409 - val_accuracy: 0.9593
# Epoch 4/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0540 - accuracy: 0.9826 - val_loss: 0.1713 - val_accuracy: 0.9617
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0448 - accuracy: 0.9858 - val_loss: 0.1340 - val_accuracy: 0.9657
# Epoch 6/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0328 - accuracy: 0.9899 - val_loss: 0.1788 - val_accuracy: 0.9593
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0334 - accuracy: 0.9893 - val_loss: 0.1602 - val_accuracy: 0.9632
# Epoch 8/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0243 - accuracy: 0.9919 - val_loss: 0.2013 - val_accuracy: 0.9602
# Epoch 9/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.0274 - accuracy: 0.9914 - val_loss: 0.1713 - val_accuracy: 0.9620
# Epoch 10/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0189 - accuracy: 0.9942 - val_loss: 0.2065 - val_accuracy: 0.9650

# %%
# VISUALIZE LOSS CURVES
# VISUALIZE
train_loss = history.history['loss']
plt.plot(train_loss, label = 'Training')

val_loss = history.history['val_loss']
plt.plot(val_loss, label = 'Validation')

plt.title('Loss After Each Epoch', fontsize = 'x-large')
plt.xlabel('Epoch', fontsize = 'x-large')
plt.ylabel('Loss', fontsize = 'x-large')
plt.legend()
plt.show()

# %%
# VISUALIZE ACCURACY CURVES
# VISUALIZE
train_accuracy = history.history['accuracy']
plt.plot(train_accuracy, label = 'Training')

val_accuracy = history.history['val_accuracy']
plt.plot(val_accuracy, label = 'Validation')

plt.title('Accuracy After Each Epoch', fontsize = 'x-large')
plt.xlabel('Epoch', fontsize = 'x-large')
plt.ylabel('Accuracy', fontsize = 'x-large')
plt.legend()
plt.show()

# %% [markdown]
# ### **Problem #2.5**
#
# **Run the code below to make predictions on the test set using your final model.**

# %%
# Make predictions and convert from probabilities of each digit to single digit
predictions = [np.argmax(d) for d in model_nn.predict(X_test)]


# Plot images with predicted labes
plt.figure(figsize=(20,5))

for i in range(5):
  plt.subplot(1, 5, i+1)
  plt.title(f"Model predicts {predictions[i]}, Actual is {np.argmax(y_test[i])}")
  plt.imshow(X_test[i], cmap='gray')
  plt.axis("off")

plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# <a name="p3"></a>
#
# ---
# ## **Part 3: [OPTIONAL] CIFAR-100 Classifiction**
# ---
#
# In the independent work section of the lab you will make a neural network that classifies images from the CIFAR-100 dataset. This dataset contains 60,000 images each of 32x32 RGB color images that belong to 1 out of 100 possible classes:
#
# 1-5) beaver, dolphin, otter, seal, whale
#
# 6-10) aquarium fish, flatfish, ray, shark, trout
#
# 11-15) orchids, poppies, roses, sunflowers, tulips
#
# 16-20) bottles, bowls, cans, cups, plates
#
# 21-25) apples, mushrooms, oranges, pears, sweet peppers
#
# 26-30) clock, computer keyboard, lamp, telephone, television
#
# 31-35) bed, chair, couch, table, wardrobe
#
# 36-40) bee, beetle, butterfly, caterpillar, cockroach
#
# 41-45) bear, leopard, lion, tiger, wolf
#
# 46-50) bridge, castle, house, road, skyscraper
#
# 51-55) cloud, forest, mountain, plain, sea
#
# 56-60) camel, cattle, chimpanzee, elephant, kangaroo
#
# 61-65) fox, porcupine, possum, raccoon, skunk
#
# 66-70) crab, lobster, snail, spider, worm
#
# 71-75) baby, boy, girl, man, woman
#
# 76-80) crocodile, dinosaur, lizard, snake, turtle
#
# 81-85) hamster, mouse, rabbit, shrew, squirrel
#
# 86-90) maple, oak, palm, pine, willow
#
# 91-95) bicycle, bus, motorcycle, pickup truck, train
#
# 96-100) lawn-mower, rocket, streetcar, tank, tractor
#
# <br>
#
# and the list of the 20 superclasses:
#
# 1) aquatic mammals (classes 1-5)
#
# 2) fish (classes 6-10)
#
# 3) flowers (classes 11-15)
#
# 4) food containers (classes 16-20)
#
# 5) fruit and vegetables (classes 21-25)
#
# 6) household electrical devices (classes 26-30)
#
# 7) household furniture (classes 31-35)
#
# 8) insects (classes 36-40)
#
# 9) large carnivores (classes 41-45)
#
# 10) large man-made outdoor things (classes 46-50)
#
# 11) large natural outdoor scenes (classes 51-55)
#
# 12) large omnivores and herbivores (classes 56-60)
#
# 13) medium-sized mammals (classes 61-65)
#
# 14) non-insect invertebrates (classes 66-70)
#
# 15) people (classes 71-75)
#
# 16) reptiles (classes 76-80)
#
# 17) small mammals (classes 81-85)
#
# 18) trees (classes 86-90)
#
# 19) vehicles 1 (classes 91-95)
#
# 20) vehicles 2 (classes 96-100)

# %% [markdown]
# ### **Problem #3.1**
#
# To get started, let's:
# 1. Load and view the data.
# 2. Scale the features.
# 3. One hot encode the labels.

# %% [markdown]
# #### **1. Load and view the data.**

# %%
(X_train, y_train), (X_test, y_test) = cifar100.load_data()


plt.figure(figsize=(20,5))

# Show a few images from the dataset
for i in range(5):
  plt.subplot(1, 5, i + 1)
  plt.title(f"Random image from class {y_train[i]}")
  plt.imshow(X_train[i], cmap='gray')
  plt.axis("off")

plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 13s 0us/step

# %% [markdown]
# #### **2. Scale the features.**
#
# Specifically, we want to just scale the inputs to be between 0 and 1 without impacting the mean or standard deviation. This means that we *don't* want to normalize or standardize. Instead, we need to scale the points from 0 - 255 to 0 - 1.

# %%
X_train = X_train/255
X_test = X_test/255

# %% [markdown]
# #### **3. One hot encode the labels.**

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# ### **Problem #3.2**
#
# Next, let's determine the shape of the data so that we know how to properly setup the input layer of our Neural Network.
#
# <br>
#
# **IMPORTANT**: While we knew there 10 digits/labels in the Part above, we may not always be familiar with the label enough to know how many unique categories there are. While this is something that is important to verify, we can quickly check how many categories were created for the label by looking at `y_train.shape`.

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 100)

# %% [markdown]
# ### **Problem #3.3**
#
# Now let's build and fit a Neural Network to classify these images. Specifically, let's:
# 1. Create a Neural Network and fit it to the training data.
# 2. Visualize the training and validation performance per epoch.
#
# <br>
#
# **NOTE**: As mentioned in Part 1, viewing the learned weights and biases is *usually* not very meaningful when there are so many of them. As such, you are not required to do that here.

# %% [markdown]
# #### **1. Create a Neural Network and fit it to the training data.**
#
# Build a NN such that it has:
# * The correct number of input neurons (one for each feature). Flattened if need be.
# * No hidden layers.
# * Ten output neurons with the `'softmax'` activation function. This is the typical output activation function for classification. **NOTE: You need one output neuron per class (letter).**
#
# <br>
#
# Train the NN such that the:
# * `loss = 'categorical_crossentropy'`. This is a typical loss function for one hot encoded categorical variables. It compares the probabilities of outputs.
# * `metrics = ['accuracy']`.

# %%
model_nn = Sequential()
model_nn.add(Flatten(input_shape = (32, 32, 3)))
model_nn.add(Dense(100, activation='softmax'))

# Compile the model
opt = Adam(learning_rate = 0.1)
model_nn.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# Fit the model on the training data
history = model_nn.fit(X_train, y_train, verbose = True, validation_split = 0.1, epochs=10, batch_size = 16)
# Out:
# Epoch 1/10
# 2813/2813 [==============================] - 10s 3ms/step - loss: 232.6003 - accuracy: 0.0532 - val_loss: 223.8277 - val_accuracy: 0.0442
# Epoch 2/10
# 2813/2813 [==============================] - 8s 3ms/step - loss: 223.4680 - accuracy: 0.0753 - val_loss: 204.7520 - val_accuracy: 0.0704
# Epoch 3/10
# 2813/2813 [==============================] - 11s 4ms/step - loss: 221.3831 - accuracy: 0.0842 - val_loss: 220.9865 - val_accuracy: 0.0786
# Epoch 4/10
# 2813/2813 [==============================] - 10s 3ms/step - loss: 223.8988 - accuracy: 0.0902 - val_loss: 242.9018 - val_accuracy: 0.0712
# Epoch 5/10
# 2813/2813 [==============================] - 10s 4ms/step - loss: 216.8888 - accuracy: 0.0963 - val_loss: 240.4279 - val_accuracy: 0.0742
# Epoch 6/10
# 2813/2813 [==============================] - 8s 3ms/step - loss: 218.9679 - accuracy: 0.1001 - val_loss: 248.0861 - val_accuracy: 0.0746
# Epoch 7/10
# 2813/2813 [==============================] - 9s 3ms/step - loss: 216.4242 - accuracy: 0.1027 - val_loss: 237.6908 - val_accuracy: 0.0824
# Epoch 8/10
# 2813/2813 [==============================] - 9s 3ms/step - loss: 217.5586 - accuracy: 0.1078 - val_loss: 238.8774 - val_accuracy: 0.0696
# Epoch 9/10
# 2813/2813 [==============================] - 10s 4ms/step - loss: 216.8430 - accuracy: 0.1114 - val_loss: 215.9835 - val_accuracy: 0.0770
# Epoch 10/10
# 2813/2813 [==============================] - 10s 4ms/step - loss: 215.7642 - accuracy: 0.1154 - val_loss: 220.1270 - val_accuracy: 0.0838

# %% [markdown]
# #### **2. Visualize the training and validation performance per epoch.**
#
# Specifically, create two plots:
# 1. The loss of the NN vs. epochs for both the training and validation sets.
#
# 2. The accuracy of the NN vs. epochs for both the training and validation sets. You can do this by replaced `'loss'` with `'accuracy'` anywhere you find it in the code.

# %%
# VISUALIZE
train_loss = history.history['loss']
plt.plot(train_loss, label = 'Training')

val_loss = history.history['val_loss']
plt.plot(val_loss, label = 'Validation')

plt.title('Loss After Each Epoch', fontsize = 'x-large')
plt.xlabel('Epoch', fontsize = 'x-large')
plt.ylabel('Loss', fontsize = 'x-large')
plt.legend()
plt.show()

# %%
# VISUALIZE
train_accuracy = history.history['accuracy']
plt.plot(train_accuracy, label = 'Training')

val_accuracy = history.history['val_accuracy']
plt.plot(val_accuracy, label = 'Validation')

plt.title('Accuracy After Each Epoch', fontsize = 'x-large')
plt.xlabel('Epoch', fontsize = 'x-large')
plt.ylabel('Accuracy', fontsize = 'x-large')
plt.legend()
plt.show()

# %% [markdown]
# ### **Problem #3.4**
#
# Now, improve this model. Consider:
# * Adding hidden layers with around the same number of neurons as there are input features (pixels).
# * Using non-linear activation functions in any hidden layers.
# * Training with a different learning rate.
# * Training with more epochs.
# * Training with a different batch size.
#
# <br>
#
# Create learning curves to ensure you are creating an improved model.

# %%
model_nn = Sequential()
model_nn.add(Flatten(input_shape = (32, 32, 3)))
model_nn.add(Dense(512, activation='relu'))
model_nn.add(Dense(256, activation='relu'))
model_nn.add(Dense(256, activation='relu'))
model_nn.add(Dense(100, activation='softmax'))

# Compile the model
opt = Adam(learning_rate = 0.0001)
model_nn.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# Fit the model on the training data
history = model_nn.fit(X_train, y_train, verbose = True, validation_split = 0.1, epochs=100, batch_size = 64)
# Out:
# Epoch 1/100
# 704/704 [==============================] - 4s 5ms/step - loss: 4.2191 - accuracy: 0.0638 - val_loss: 3.9729 - val_accuracy: 0.1058
# Epoch 2/100
# 704/704 [==============================] - 3s 4ms/step - loss: 3.8309 - accuracy: 0.1216 - val_loss: 3.7794 - val_accuracy: 0.1336
# Epoch 3/100
# 704/704 [==============================] - 4s 5ms/step - loss: 3.6630 - accuracy: 0.1508 - val_loss: 3.6970 - val_accuracy: 0.1446
# Epoch 4/100
# 704/704 [==============================] - 3s 4ms/step - loss: 3.5604 - accuracy: 0.1703 - val_loss: 3.5991 - val_accuracy: 0.1634
# Epoch 5/100
# 704/704 [==============================] - 4s 5ms/step - loss: 3.4753 - accuracy: 0.1861 - val_loss: 3.5395 - val_accuracy: 0.1734
# Epoch 6/100
# 704/704 [==============================] - 3s 4ms/step - loss: 3.3993 - accuracy: 0.1972 - val_loss: 3.4974 - val_accuracy: 0.1810
# Epoch 7/100
# 704/704 [==============================] - 4s 5ms/step - loss: 3.3378 - accuracy: 0.2114 - val_loss: 3.4485 - val_accuracy: 0.1926
# Epoch 8/100
# 704/704 [==============================] - 3s 4ms/step - loss: 3.2770 - accuracy: 0.2204 - val_loss: 3.4178 - val_accuracy: 0.1958
# Epoch 9/100
# 704/704 [==============================] - 3s 5ms/step - loss: 3.2229 - accuracy: 0.2272 - val_loss: 3.3783 - val_accuracy: 0.2032
# Epoch 10/100
# 704/704 [==============================] - 3s 4ms/step - loss: 3.1708 - accuracy: 0.2380 - val_loss: 3.3566 - val_accuracy: 0.2040
# Epoch 11/100
# 704/704 [==============================] - 4s 5ms/step - loss: 3.1200 - accuracy: 0.2491 - val_loss: 3.3355 - val_accuracy: 0.2132
# Epoch 12/100
# 704/704 [==============================] - 3s 4ms/step - loss: 3.0735 - accuracy: 0.2575 - val_loss: 3.3118 - val_accuracy: 0.2166
# Epoch 13/100
# 704/704 [==============================] - 3s 4ms/step - loss: 3.0256 - accuracy: 0.2673 - val_loss: 3.3049 - val_accuracy: 0.2090
# Epoch 14/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.9816 - accuracy: 0.2761 - val_loss: 3.3140 - val_accuracy: 0.2170
# Epoch 15/100
# 704/704 [==============================] - 3s 5ms/step - loss: 2.9407 - accuracy: 0.2828 - val_loss: 3.2876 - val_accuracy: 0.2196
# Epoch 16/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.9023 - accuracy: 0.2890 - val_loss: 3.2693 - val_accuracy: 0.2162
# Epoch 17/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.8588 - accuracy: 0.2971 - val_loss: 3.2739 - val_accuracy: 0.2288
# Epoch 18/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.8224 - accuracy: 0.3050 - val_loss: 3.2272 - val_accuracy: 0.2366
# Epoch 19/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.7870 - accuracy: 0.3123 - val_loss: 3.1978 - val_accuracy: 0.2404
# Epoch 20/100
# 704/704 [==============================] - 3s 5ms/step - loss: 2.7437 - accuracy: 0.3218 - val_loss: 3.2135 - val_accuracy: 0.2366
# Epoch 21/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.7098 - accuracy: 0.3289 - val_loss: 3.2095 - val_accuracy: 0.2380
# Epoch 22/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.6754 - accuracy: 0.3368 - val_loss: 3.2166 - val_accuracy: 0.2388
# Epoch 23/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.6370 - accuracy: 0.3458 - val_loss: 3.1814 - val_accuracy: 0.2492
# Epoch 24/100
# 704/704 [==============================] - 3s 5ms/step - loss: 2.6056 - accuracy: 0.3523 - val_loss: 3.1899 - val_accuracy: 0.2462
# Epoch 25/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.5707 - accuracy: 0.3580 - val_loss: 3.1709 - val_accuracy: 0.2520
# Epoch 26/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.5363 - accuracy: 0.3662 - val_loss: 3.1824 - val_accuracy: 0.2456
# Epoch 27/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.5029 - accuracy: 0.3732 - val_loss: 3.2060 - val_accuracy: 0.2460
# Epoch 28/100
# 704/704 [==============================] - 3s 5ms/step - loss: 2.4677 - accuracy: 0.3803 - val_loss: 3.2049 - val_accuracy: 0.2454
# Epoch 29/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.4364 - accuracy: 0.3856 - val_loss: 3.2186 - val_accuracy: 0.2496
# Epoch 30/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.3976 - accuracy: 0.3958 - val_loss: 3.2010 - val_accuracy: 0.2490
# Epoch 31/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.3672 - accuracy: 0.4012 - val_loss: 3.2144 - val_accuracy: 0.2482
# Epoch 32/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.3315 - accuracy: 0.4115 - val_loss: 3.2041 - val_accuracy: 0.2540
# Epoch 33/100
# 704/704 [==============================] - 3s 5ms/step - loss: 2.3016 - accuracy: 0.4168 - val_loss: 3.2078 - val_accuracy: 0.2536
# Epoch 34/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.2672 - accuracy: 0.4264 - val_loss: 3.2241 - val_accuracy: 0.2558
# Epoch 35/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.2345 - accuracy: 0.4309 - val_loss: 3.2270 - val_accuracy: 0.2522
# Epoch 36/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.2064 - accuracy: 0.4394 - val_loss: 3.2294 - val_accuracy: 0.2598
# Epoch 37/100
# 704/704 [==============================] - 4s 5ms/step - loss: 2.1754 - accuracy: 0.4458 - val_loss: 3.2598 - val_accuracy: 0.2514
# Epoch 38/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1434 - accuracy: 0.4519 - val_loss: 3.2515 - val_accuracy: 0.2632
# Epoch 39/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1157 - accuracy: 0.4602 - val_loss: 3.2794 - val_accuracy: 0.2474
# Epoch 40/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0834 - accuracy: 0.4674 - val_loss: 3.3290 - val_accuracy: 0.2500
# Epoch 41/100
# 704/704 [==============================] - 3s 5ms/step - loss: 2.0497 - accuracy: 0.4746 - val_loss: 3.3218 - val_accuracy: 0.2546
# Epoch 42/100
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0226 - accuracy: 0.4806 - val_loss: 3.3023 - val_accuracy: 0.2602
# Epoch 43/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9902 - accuracy: 0.4879 - val_loss: 3.3143 - val_accuracy: 0.2546
# Epoch 44/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9645 - accuracy: 0.4932 - val_loss: 3.3385 - val_accuracy: 0.2560
# Epoch 45/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9317 - accuracy: 0.5032 - val_loss: 3.3262 - val_accuracy: 0.2496
# Epoch 46/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9025 - accuracy: 0.5084 - val_loss: 3.3369 - val_accuracy: 0.2564
# Epoch 47/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8732 - accuracy: 0.5207 - val_loss: 3.3517 - val_accuracy: 0.2598
# Epoch 48/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8484 - accuracy: 0.5210 - val_loss: 3.3513 - val_accuracy: 0.2566
# Epoch 49/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8158 - accuracy: 0.5297 - val_loss: 3.4344 - val_accuracy: 0.2448
# Epoch 50/100
# 704/704 [==============================] - 3s 5ms/step - loss: 1.7891 - accuracy: 0.5374 - val_loss: 3.3971 - val_accuracy: 0.2584
# Epoch 51/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.7614 - accuracy: 0.5448 - val_loss: 3.4358 - val_accuracy: 0.2548
# Epoch 52/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.7329 - accuracy: 0.5503 - val_loss: 3.4579 - val_accuracy: 0.2572
# Epoch 53/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.7086 - accuracy: 0.5574 - val_loss: 3.4961 - val_accuracy: 0.2598
# Epoch 54/100
# 704/704 [==============================] - 4s 5ms/step - loss: 1.6826 - accuracy: 0.5657 - val_loss: 3.5223 - val_accuracy: 0.2522
# Epoch 55/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.6508 - accuracy: 0.5734 - val_loss: 3.5148 - val_accuracy: 0.2552
# Epoch 56/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.6280 - accuracy: 0.5774 - val_loss: 3.5187 - val_accuracy: 0.2584
# Epoch 57/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.5987 - accuracy: 0.5863 - val_loss: 3.5495 - val_accuracy: 0.2528
# Epoch 58/100
# 704/704 [==============================] - 3s 5ms/step - loss: 1.5744 - accuracy: 0.5905 - val_loss: 3.5972 - val_accuracy: 0.2514
# Epoch 59/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.5476 - accuracy: 0.5970 - val_loss: 3.6226 - val_accuracy: 0.2540
# Epoch 60/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.5242 - accuracy: 0.6009 - val_loss: 3.6035 - val_accuracy: 0.2536
# Epoch 61/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.4952 - accuracy: 0.6122 - val_loss: 3.6813 - val_accuracy: 0.2498
# Epoch 62/100
# 704/704 [==============================] - 3s 5ms/step - loss: 1.4746 - accuracy: 0.6149 - val_loss: 3.7014 - val_accuracy: 0.2526
# Epoch 63/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.4471 - accuracy: 0.6233 - val_loss: 3.7488 - val_accuracy: 0.2466
# Epoch 64/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.4189 - accuracy: 0.6302 - val_loss: 3.7755 - val_accuracy: 0.2444
# Epoch 65/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.3996 - accuracy: 0.6352 - val_loss: 3.7141 - val_accuracy: 0.2550
# Epoch 66/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.3751 - accuracy: 0.6401 - val_loss: 3.7670 - val_accuracy: 0.2470
# Epoch 67/100
# 704/704 [==============================] - 3s 5ms/step - loss: 1.3497 - accuracy: 0.6468 - val_loss: 3.8330 - val_accuracy: 0.2522
# Epoch 68/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.3251 - accuracy: 0.6532 - val_loss: 3.8828 - val_accuracy: 0.2424
# Epoch 69/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.3056 - accuracy: 0.6592 - val_loss: 3.9131 - val_accuracy: 0.2432
# Epoch 70/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.2807 - accuracy: 0.6644 - val_loss: 3.8796 - val_accuracy: 0.2462
# Epoch 71/100
# 704/704 [==============================] - 3s 5ms/step - loss: 1.2585 - accuracy: 0.6725 - val_loss: 3.8897 - val_accuracy: 0.2518
# Epoch 72/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.2328 - accuracy: 0.6800 - val_loss: 3.9299 - val_accuracy: 0.2474
# Epoch 73/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.2128 - accuracy: 0.6834 - val_loss: 3.9529 - val_accuracy: 0.2486
# Epoch 74/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.1900 - accuracy: 0.6908 - val_loss: 4.0236 - val_accuracy: 0.2468
# Epoch 75/100
# 704/704 [==============================] - 4s 5ms/step - loss: 1.1706 - accuracy: 0.6965 - val_loss: 4.1430 - val_accuracy: 0.2426
# Epoch 76/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.1460 - accuracy: 0.7005 - val_loss: 4.0670 - val_accuracy: 0.2484
# Epoch 77/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.1256 - accuracy: 0.7087 - val_loss: 4.1386 - val_accuracy: 0.2434
# Epoch 78/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.1040 - accuracy: 0.7149 - val_loss: 4.1171 - val_accuracy: 0.2424
# Epoch 79/100
# 704/704 [==============================] - 4s 5ms/step - loss: 1.0804 - accuracy: 0.7214 - val_loss: 4.1381 - val_accuracy: 0.2474
# Epoch 80/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.0616 - accuracy: 0.7240 - val_loss: 4.2126 - val_accuracy: 0.2540
# Epoch 81/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.0430 - accuracy: 0.7307 - val_loss: 4.2898 - val_accuracy: 0.2432
# Epoch 82/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.0176 - accuracy: 0.7361 - val_loss: 4.2617 - val_accuracy: 0.2476
# Epoch 83/100
# 704/704 [==============================] - 3s 4ms/step - loss: 1.0054 - accuracy: 0.7385 - val_loss: 4.3212 - val_accuracy: 0.2442
# Epoch 84/100
# 704/704 [==============================] - 3s 5ms/step - loss: 0.9804 - accuracy: 0.7471 - val_loss: 4.3849 - val_accuracy: 0.2360
# Epoch 85/100
# 704/704 [==============================] - 3s 4ms/step - loss: 0.9618 - accuracy: 0.7533 - val_loss: 4.4218 - val_accuracy: 0.2448
# Epoch 86/100
# 704/704 [==============================] - 3s 4ms/step - loss: 0.9436 - accuracy: 0.7582 - val_loss: 4.4213 - val_accuracy: 0.2426
# Epoch 87/100
# 704/704 [==============================] - 3s 4ms/step - loss: 0.9286 - accuracy: 0.7583 - val_loss: 4.4559 - val_accuracy: 0.2428
# Epoch 88/100
# 704/704 [==============================] - 3s 5ms/step - loss: 0.9058 - accuracy: 0.7630 - val_loss: 4.4736 - val_accuracy: 0.2424
# Epoch 89/100
# 704/704 [==============================] - 3s 4ms/step - loss: 0.8885 - accuracy: 0.7697 - val_loss: 4.5018 - val_accuracy: 0.2428
# Epoch 90/100
# 704/704 [==============================] - 3s 4ms/step - loss: 0.8661 - accuracy: 0.7766 - val_loss: 4.5805 - val_accuracy: 0.2438
# Epoch 91/100
# 704/704 [==============================] - 3s 4ms/step - loss: 0.8477 - accuracy: 0.7830 - val_loss: 4.6166 - val_accuracy: 0.2426
# Epoch 92/100
# 704/704 [==============================] - 4s 5ms/step - loss: 0.8337 - accuracy: 0.7845 - val_loss: 4.6363 - val_accuracy: 0.2414
# Epoch 93/100
# 704/704 [==============================] - 3s 4ms/step - loss: 0.8185 - accuracy: 0.7889 - val_loss: 4.6996 - val_accuracy: 0.2444
# Epoch 94/100
# 704/704 [==============================] - 3s 4ms/step - loss: 0.8024 - accuracy: 0.7920 - val_loss: 4.7115 - val_accuracy: 0.2396
# Epoch 95/100
# 704/704 [==============================] - 3s 4ms/step - loss: 0.7846 - accuracy: 0.7984 - val_loss: 4.6933 - val_accuracy: 0.2398
# Epoch 96/100
# 704/704 [==============================] - 3s 5ms/step - loss: 0.7615 - accuracy: 0.8059 - val_loss: 4.8347 - val_accuracy: 0.2350
# Epoch 97/100
# 704/704 [==============================] - 3s 4ms/step - loss: 0.7509 - accuracy: 0.8065 - val_loss: 4.8164 - val_accuracy: 0.2446
# Epoch 98/100
# 704/704 [==============================] - 3s 4ms/step - loss: 0.7379 - accuracy: 0.8088 - val_loss: 4.8965 - val_accuracy: 0.2404
# Epoch 99/100
# 704/704 [==============================] - 3s 4ms/step - loss: 0.7201 - accuracy: 0.8158 - val_loss: 4.8555 - val_accuracy: 0.2436
# Epoch 100/100
# 704/704 [==============================] - 3s 4ms/step - loss: 0.6987 - accuracy: 0.8220 - val_loss: 4.9230 - val_accuracy: 0.2382

# %%
# VISUALIZE
train_loss = history.history['loss']
plt.plot(train_loss, label = 'Training')

val_loss = history.history['val_loss']
plt.plot(val_loss, label = 'Validation')

plt.title('Loss After Each Epoch', fontsize = 'x-large')
plt.xlabel('Epoch', fontsize = 'x-large')
plt.ylabel('Loss', fontsize = 'x-large')
plt.legend()
plt.show()

# %%
# VISUALIZE ACCURACY CURVES
train_accuracy = history.history['accuracy']
plt.plot(train_accuracy, label = 'Training')

val_accuracy = history.history['val_accuracy']
plt.plot(val_accuracy, label = 'Validation')

plt.title('Accuracy After Each Epoch', fontsize = 'x-large')
plt.xlabel('Epoch', fontsize = 'x-large')
plt.ylabel('Accuracy', fontsize = 'x-large')
plt.legend()
plt.show()

# %% [markdown]
# ### **Problem #3.5**
#
# Complete the code below to make predictions on the test set using your final model.

# %%
# Make predictions and convert from probabilities of each digit to single digit
predictions = [np.argmax(d) for d in model_nn.predict(X_test)]


# Plot images with predicted labels
plt.figure(figsize=(20,5))

for i in range(5):
  plt.subplot(1, 5, i+1)
  plt.title(f"Model predicts {predictions[i]}, Actual is {np.argmax(y_test[i])}")
  plt.imshow(X_test[i], cmap='gray')
  plt.axis("off")

plt.show()
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# ### **Reflection Questions**
#
# To complete this section, answer the following reflection questions:
#
# 1. What model architecture and set of hyperparameters that you tried produced the best model? The worst model?
#
# 2. How generalizable do you believe your best model is? In other words, how well do you believe your model will handle unseen data?
#
# 3. How does your best model compare to one that makes completely random guesses? In other words, what would the accuracy of a model be that randomly guesses 1 out of the 100 classes each time?

# %% [markdown]
# #End of notebook
# ---
# © 2023 The Coding School, All rights reserved
